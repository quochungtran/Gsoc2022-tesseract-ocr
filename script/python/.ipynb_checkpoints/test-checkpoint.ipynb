# %%
import matplotlib.pyplot as plt
import cv2 
import pytesseract
import numpy as np
import os
from pytesseract import Output

import pre_processing
from pre_processing import Square

# %%
a = Square(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 a = Square(10)
#
# NameError: name 'Square' is not defined

# %%
DATA_PATH = "../../Data"

# %%
img_test_file = os.path.join(DATA_PATH, "Japon19441222_original.png")
img = cv2.imread(img_test_file)

# %% [markdown]
# # Preprocessing for Tesseract

# %%
# Get information about orientation and script detection

pytesseract.image_to_osd(img), output_type=Output.DICT)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 3>()
#       1 # Get information about orientation and script detection
# ----> 3 print(pytesseract.image_to_osd(img), output_type=Output.DICT)
#
# TypeError: 'output_type' is an invalid keyword argument for print()

# %%
gray = get_grayscale(img)

# %%
pre_process_engine = PreProcessing_engine(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 pre_process_engine = PreProcessing_engine(img)
#
# NameError: name 'PreProcessing_engine' is not defined

# %% [markdown]
# # Tesseract processing

# %%
results = pytesseract.image_to_data(img, output_type=Output.DICT)

# %%
for i in range(0, len(results["text"])):
    x = results["left"][i]
    y = results["top"][i]
    
    w = results["width"][i]
    h = results["height"][i]
    text = results["text"][i]
    conf = int(results["conf"][i])
    if conf > 70:
        text = "".join([c if ord(c) < 128 else "" for c in text]).strip()
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(img, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 200), 2)

# %%
#Show the image with matplotlib

from matplotlib.pyplot import figure
figure(figsize=(10, 30), dpi=80)

plt.imshow(img)
plt.show()
